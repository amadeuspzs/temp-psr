# %% [markdown]
# # Interview Exercise - Data Scientist
#
# ## Introduction
#
# This notebook contains a series of exercises to assist in identifying a **Senior Data Scientist Contractor** for the NHS AI Lab Skunkworks SWAT team.
#
# ### What is a SWAT Team?
#
# A SWAT team is a rapid action team spun up to assist an NHS organisation, such as a trust, build and/or implement an AI solution. This may be a new project built from scratch, or a continuation of a project that we have released as Open Source on our [Github](https://github.com/nhsx).
#
# ### What is the goal of this exercise?
#
# This is not a Google coding interview. The goal is to ensure sufficient proficiency with the data science tools required for this project, but above all, the **ability to learn quickly, and experiment**.
#
# * Feel free to Google/Stackoverflow for help during this process ("open book")
# * Don't worry about completing all the exercises during the alloted time.
#
# ## Instructions
#
# * You will be presented with a number of activities below
# * Read the tasks carefully, and when you're ready, start coding.
# * The focus is the process and the way you approach the problem. There is no expectation that a highly accurate model will be produced as part of these exercises, instead the aim is understand your methodology.
# * There will be plenty of time to discuss the way you tackled the exercises and how you would have done it differently with more time.
#
#
# ## Exercise 1 - Working with pandas

# %%
# 1.1 Load the dataset

# 1.2 Give a quick overview of summary statistics for continuous variables in the dataset

# 1.3 Check for missing values - any action needed?

# 1.4 Calculate the mean Length of Stay for each category of 'Severity of Illness'

# 1.5 Visualise distribution of Length of Stay

# 1.6 Store a .csv file of all patients in the 'TB & Chest disease' department. Name the file 'chest_disease.csv'

# %% [markdown]
# ## Exercise 2 - scikit-learn
#
# The aim of this exercise is to predict how many days (to the nearest whole day) someone will stay in hospital at admission.
#
# Given the time constraints here, please bear in mind that this isn't about producing a well-performing model. Instead, we're interested in the way you approach the problem and how you solve it

# %%
# 2.1 Convert categorical features and select which categorical features are to be used with a SK-Learn predictor model

# 2.2 Appropriately split data into divisions for producing model

# 2.3 Initialise and train your chosen model

# 2.4 Assess how good your model is

# %% [markdown]
# ## Exercise 3 - Visualise results
#
# Now that you have your model, imagine that you need to explain how the model would help a clinician involved with admitting patients to a hospital.
#
# Produce one visualisation which would help you accomplish this. We will talk through your chosen visual at the interview.

# %%
# 3.1 Produce a visualisation to help explain how your model is useful
